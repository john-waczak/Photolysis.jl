# %% [markdown]
# # $\mathrm{(CH_3)_3CONO_2}$ (tert-butyl nitrate)

# %%
using Pkg 
Pkg.activate("../")
# Out:
#   Activating project at `~/gitrepos/activepure/Photolysis.jl/mcm`

# %%
using Plots, MLPlotRecipes
using HDF5
using Tables, DataFrames, CSV
using MLJ, MLJGaussianProcesses
using StatsBase 
using KernelFunctions
using ParameterHandling

# %%
include("./utils.jl")
# Out:
# filter_outliers (generic function with 1 method)

# %%
# load in spectrometer data
hr4000_df = CSV.File("../hr4000_wavelengths.txt") |> DataFrame ;

# %% [markdown]
# # Model Evaluation

# %%
λ = hr4000_df.λ
Φ = zeros(size(λ))

idxs = [idx for idx ∈ 1:size(λ,1) if λ[idx] ≥ 270.0 && λ[idx] ≤ 330.0 ]
Φ[idxs] .= 1.0



p = plot(
    λ,
    Φ,
    xlabel="λ [nm]",
    ylabel="Φ",
    alpha=0.7,
    lw=3,
    label="",
    title="Quantum Yield for (CH₃)₃CONO₂ → t-C₄H₉O + NO₂",
    titlefontsize=12,
)

# %% [markdown]
# # Output for Photolysis Rate Determination

# %%
df_photolysis_Φ = CSV.File("../photolysis_Φ.csv") |> DataFrame;

describe(df_photolysis_Φ)
# Out:
# 32×7 DataFrame
#  Row │ variable  mean        min      median   max       nmissing  eltype
#      │ Symbol    Float64     Float64  Float64  Float64   Int64     DataType
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │ Φ_1       0.114981        0.0      0.0  1.0              0  Float64
#    2 │ Φ_2       0.885019        0.0      1.0  1.0              0  Float64
#    3 │ Φ_3       0.963542        0.0      1.0  1.0              0  Float64
#    4 │ Φ_4       0.214167        0.0      0.0  1.0              0  Float64
#    5 │ Φ_6       0.426121        0.0      0.0  1.0              0  Float64
#    6 │ Φ_5       0.00986771      0.0      0.0  0.344696         0  Float64
#    7 │ Φ_7       0.211623        0.0      0.0  1.0              0  Float64
#    8 │ Φ_8       0.945175        0.0      1.0  1.0              0  Float64
#    9 │ Φ_11      0.0470227       0.0      0.0  0.73106          0  Float64
#   10 │ Φ_12      0.0453115       0.0      0.0  0.709551         0  Float64
#   11 │ Φ_13      0.107152        0.0      0.0  1.0              0  Float64
#   ⋮  │    ⋮          ⋮          ⋮        ⋮        ⋮         ⋮         ⋮
#   23 │ Φ_31      0.0643781       0.0      0.0  1.0              0  Float64
#   24 │ Φ_32      0.0581717       0.0      0.0  0.647131         0  Float64
#   25 │ Φ_33      0.0479147       0.0      0.0  0.459975         0  Float64
#   26 │ Φ_34      0.158096        0.0      0.0  1.0              0  Float64
#   27 │ Φ_35      0.0278492       0.0      0.0  0.158            0  Float64
#   28 │ Φ_41      0.902138        0.0      1.0  1.0              0  Float64
#   29 │ Φ_51      0.945175        0.0      1.0  1.0              0  Float64
#   30 │ Φ_52      0.0515351       0.0      0.0  1.0              0  Float64
#   31 │ Φ_53      0.169956        0.0      0.0  1.0              0  Float64
#   32 │ Φ_54      0.169956        0.0      0.0  1.0              0  Float64
#                                                              11 rows omitted

# %%
df_photolysis_Φ.Φ_55 = Φ

describe(df_photolysis_Φ)
# Out:
# 33×7 DataFrame
#  Row │ variable  mean        min      median   max       nmissing  eltype
#      │ Symbol    Float64     Float64  Float64  Float64   Int64     DataType
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │ Φ_1       0.114981        0.0      0.0  1.0              0  Float64
#    2 │ Φ_2       0.885019        0.0      1.0  1.0              0  Float64
#    3 │ Φ_3       0.963542        0.0      1.0  1.0              0  Float64
#    4 │ Φ_4       0.214167        0.0      0.0  1.0              0  Float64
#    5 │ Φ_6       0.426121        0.0      0.0  1.0              0  Float64
#    6 │ Φ_5       0.00986771      0.0      0.0  0.344696         0  Float64
#    7 │ Φ_7       0.211623        0.0      0.0  1.0              0  Float64
#    8 │ Φ_8       0.945175        0.0      1.0  1.0              0  Float64
#    9 │ Φ_11      0.0470227       0.0      0.0  0.73106          0  Float64
#   10 │ Φ_12      0.0453115       0.0      0.0  0.709551         0  Float64
#   11 │ Φ_13      0.107152        0.0      0.0  1.0              0  Float64
#   ⋮  │    ⋮          ⋮          ⋮        ⋮        ⋮         ⋮         ⋮
#   24 │ Φ_32      0.0581717       0.0      0.0  0.647131         0  Float64
#   25 │ Φ_33      0.0479147       0.0      0.0  0.459975         0  Float64
#   26 │ Φ_34      0.158096        0.0      0.0  1.0              0  Float64
#   27 │ Φ_35      0.0278492       0.0      0.0  0.158            0  Float64
#   28 │ Φ_41      0.902138        0.0      1.0  1.0              0  Float64
#   29 │ Φ_51      0.945175        0.0      1.0  1.0              0  Float64
#   30 │ Φ_52      0.0515351       0.0      0.0  1.0              0  Float64
#   31 │ Φ_53      0.169956        0.0      0.0  1.0              0  Float64
#   32 │ Φ_54      0.169956        0.0      0.0  1.0              0  Float64
#   33 │ Φ_55      0.0616776       0.0      0.0  1.0              0  Float64
#                                                              12 rows omitted

# %%
CSV.write("../photolysis_Φ.csv", df_photolysis_Φ)
# Out:
# "../photolysis_Φ.csv"
